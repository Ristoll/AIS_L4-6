# %% [markdown]
# <a href="https://colab.research.google.com/github/Ristoll/AIS_Labs/blob/main/Lab7_task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
from sklearn import linear_model
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures

# 1. Завантаження даних
input_file = 'data_multivar_regr.txt'
data = np.loadtxt(input_file, delimiter=',')

# 2. Поділ на ознаки (X) та цільову змінну (y)
x, y = data[:, :-1], data[:, -1]

# 3. Поділ на навчальну та тестову вибірки (80% / 20%)
num_training = int(0.8 * len(x))
num_test = len(x) - num_training

x_train, y_train = x[:num_training], y[:num_training]
x_test, y_test = x[num_training:], y[num_training:]

# 4. Створення та навчання моделі лінійної регресії
regressor = linear_model.LinearRegression()
regressor.fit(x_train, y_train)

# 5. Прогнозування для тестових даних
y_test_pred = regressor.predict(x_test)

# 6. Виведення показників якості моделі
print("Linear Regressor performance:")
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_test_pred), 2))
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_test_pred), 2))
print("Median absolute error =", round(sm.median_absolute_error(y_test, y_test_pred), 2))
print("Explained variance score =", round(sm.explained_variance_score(y_test, y_test_pred), 2))
print("R2 score =", round(sm.r2_score(y_test, y_test_pred), 2))

# 7. Збереження моделі у файл
output_model_file = 'model_multivar.pkl'
with open(output_model_file, 'wb') as f:
    pickle.dump(regressor, f)

# 8. Перевірка точності моделі після збереження
y_test_pred_new = regressor.predict(x_test)
print("\nNew mean absolute error =", round(sm.mean_absolute_error(y_test, y_test_pred_new), 2))

polynomical = PolynomialFeatures(degree=10)
x_train_transformed = polynomical.fit_transform(x_train)
datapoint = [[7.75, 6.35, 5.56]]
poly_datapoint = polynomical.fit_transform(datapoint)
poly_linear_model = linear_model.LinearRegression()
poly_linear_model.fit(x_train_transformed, y_train)
print("\nLinear regression:\n", regressor.predict(datapoint))
print("\nPolinomical regression:\n", poly_linear_model.predict(poly_datapoint))
# Out:
# Linear Regressor performance:
# Mean absolute error = 3.58
# Mean squared error = 20.31
# Median absolute error = 2.99
# Explained variance score = 0.86
# R2 score = 0.86
#
# New mean absolute error = 3.58
#
# Linear regression:
#  [36.05286276]
#
# Polinomical regression:
#  [41.08312885]

# %%
from google.colab import files

uploaded = files.upload()  # Відкриється вікно вибору файлу
for filename in uploaded.keys():
    print("Завантажено файл:", filename)
# Out:
#      <input type="file" id="files-59bcbfba-2244-46bf-88e5-3db1b2897943" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-59bcbfba-2244-46bf-88e5-3db1b2897943">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
